# %%
import os

os.chdir(r"C:\Users\USER\Desktop\code\NeuroClear")
print(os.getcwd())
# Out:
# C:\Users\USER\Desktop\code\NeuroClear

# %%
import librosa
array, sampling_rate = librosa.load(r"data/sliced/sample_2/009_STRING.wav")
f"Sample Rate: {sampling_rate} | Array len: {len(array)} | Time: {len(array)/sampling_rate:.3f}sec"
# Out:
# 'Sample Rate: 22050 | Array len: 52920 | Time: 2.400sec'

# %%
import matplotlib.pyplot as plt

plt.figure().set_figwidth(12)
librosa.display.waveshow(array, sr=sampling_rate)
plt.show()
